# %% [markdown]
# ## Section transports

# %%
# %%capture 
# comment above line to see details about the run(s) displayed
from misc import *;
# %matplotlib inline

# %%
transports = []
for path, case in zip(ocn_path, casename):
  ds = xr.open_dataset(path+case+'_section_transports.nc').sel(time=slice('0001-01-01',end_date))
  transports.append(ds)

# %%
def plotPanel(section,n,label):
    ax = plt.subplot(7,3,n+1)
    plt.plot(section.time,section.values, lw=2, label=label)
    plt.title(section.sections.values,fontsize=12)
    plt.grid()
    if n in [0,3,6,9,12,15,18]: plt.ylabel('Transport (Sv)')
    
    return

# %%
fig = plt.figure(figsize=(18,18))
for n in range(0,len(ds.sections)): 
  for i in range(0,len(casename)):
    plotPanel(transports[i].transport[n,:],n,label[i])
    
fig.text(0.5,0.9,'Case = '+str(casename[0]),horizontalalignment='center',fontsize=14)
plt.subplots_adjust(hspace=0.3)
plt.legend(fontsize=12);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/nc_time_axis/__init__.py in convert(cls, value, unit, axis)
#     539             value = value.reshape(-1)
# --> 540             first_value = value[0]
#     541         else:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# /glade/derecho/scratch/gmarques/tmp/ipykernel_15900/1352513395.py in <module>
#       2 for n in range(0,len(ds.sections)):
#       3   for i in range(0,len(casename)):
# ----> 4     plotPanel(transports[i].transport[n,:],n,label[i])
#       5
#       6 fig.text(0.5,0.9,'Case = '+str(casename[0]),horizontalalignment='center',fontsize=14)
#
# /glade/derecho/scratch/gmarques/tmp/ipykernel_15900/569673531.py in plotPanel(section, n, label)
#       1 def plotPanel(section,n,label):
#       2     ax = plt.subplot(7,3,n+1)
# ----> 3     plt.plot(section.time,section.values, lw=2, label=label)
#       4     plt.title(section.sections.values,fontsize=12)
#       5     plt.grid()
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     491
#     492         if self.axes.xaxis is not None:
# --> 493             self.axes.xaxis.update_units(x)
#     494         if self.axes.yaxis is not None:
#     495             self.axes.yaxis.update_units(y)
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/axis.py in update_units(self, data)
#    1449         default = self.converter.default_units(data, self)
#    1450         if default is not None and self.units is None:
# -> 1451             self.set_units(default)
#    1452
#    1453         elif neednew:
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/axis.py in set_units(self, u)
#    1536             axis.units = u
#    1537             axis._update_axisinfo()
# -> 1538             axis.callbacks.process('units')
#    1539             axis.callbacks.process('units finalize')
#    1540             axis.stale = True
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     290                 except Exception as exc:
#     291                     if self.exception_handler is not None:
# --> 292                         self.exception_handler(exc)
#     293                     else:
#     294                         raise
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     285             if func is not None:
#     286                 try:
# --> 287                     func(*args, **kwargs)
#     288                 # this does not capture KeyboardInterrupt, SystemExit,
#     289                 # and GeneratorExit
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/axes/_base.py in _unit_change_handler(self, axis_name, event)
#    2424         _api.check_in_list(self._get_axis_map(), axis_name=axis_name)
#    2425         for line in self.lines:
# -> 2426             line.recache_always()
#    2427         self.relim()
#    2428         self._request_autoscale_view(scalex=(axis_name == "x"),
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/lines.py in recache_always(self)
#     645
#     646     def recache_always(self):
# --> 647         self.recache(always=True)
#     648
#     649     def recache(self, always=False):
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/lines.py in recache(self, always)
#     649     def recache(self, always=False):
#     650         if always or self._invalidx:
# --> 651             xconv = self.convert_xunits(self._xorig)
#     652             x = _to_unmasked_float_array(xconv).ravel()
#     653         else:
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     250         if ax is None or ax.xaxis is None:
#     251             return x
# --> 252         return ax.xaxis.convert_units(x)
#     253
#     254     def convert_yunits(self, y):
#
# /glade/work/gmarques/miniconda/envs/dev2/lib/python3.9/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
# -> 1508             raise munits.ConversionError('Failed to convert value(s) to axis '
#    1509                                          f'units: {x!r}') from e
#    1510         return ret
#
# ConversionError: Failed to convert value(s) to axis units: array([], dtype=object)
