# %%
import xarray as xr
import numpy as np 
import matplotlib.pyplot as plt
import datetime
import glob
import os

# %%
mainDir = '/glade/p/cgd/amp/rneale/data/TRMM/1deg/'

listFiles = np.sort(glob.glob(mainDir+'3B42.??????.3hr_V7.1x1.nc'))

# %%
trmm_3hr = xr.open_mfdataset(listFiles, concat_dim='time', 
                            combine='nested', decode_times=True, 
                            data_vars='minimal')

# %%
testDaily = trmm_3hr.resample(time='1D').mean()

# %%
testDaily.time.values
# Out:
# array(['1998-01-01T00:00:00.000000000', '1998-01-02T00:00:00.000000000',
#        '1998-01-03T00:00:00.000000000', ...,
#        '2013-12-29T00:00:00.000000000', '2013-12-30T00:00:00.000000000',
#        '2013-12-31T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
sampleTest = trmm_3hr.precip.isel(time=np.arange(0,10)).load()

# %%
sampleTest.time
# Out:
# <xarray.DataArray 'time' (time: 10)>
# array(['1998-01-01T00:00:00.000000000', '1998-01-01T03:00:00.000000000',
#        '1998-01-01T06:00:00.000000000', '1998-01-01T09:00:00.000000000',
#        '1998-01-01T12:00:00.000000000', '1998-01-01T15:00:00.000000000',
#        '1998-01-01T18:00:00.000000000', '1998-01-01T21:00:00.000000000',
#        '1998-01-02T00:00:00.000000000', '1998-01-02T03:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1998-01-01 ... 1998-01-02T03:00:00
